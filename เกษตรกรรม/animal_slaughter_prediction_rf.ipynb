# %% [markdown]
# # 📊 พยากรณ์ปริมาณการฆ่าสัตว์และประเมินกำลังการผลิตเนื้อสัตว์รายจังหวัด (Animal Slaughter Volume & Capacity Prediction - Random Forest)
# ## คลาสเรียนรู้ Machine Learning สำหรับการวิเคราะห์ความสัมพันธ์และพยากรณ์ปริมาณการแปรรูปปศุสัตว์
# ### 📊 แสดงผลแผนภูมิด้วย Plotly (Interactive Chart) เพื่อความสวยงามระดับ Premium และรองรับภาษาไทย 100%
#
# ---
#
# ### 📋 วัตถุประสงค์
# 1. รวมข้อมูลการปศุสัตว์รายจังหวัด (จำนวนประชากรสัตว์ และ จำนวนครัวเรือนเกษตรกร) ร่วมกับสถิติการอนุญาตให้ฆ่าสัตว์เพื่อการบริโภค
# 2. เรียนรู้การเตรียมข้อมูล (Data Preprocessing) และการจัดการกับค่าที่สูญหาย (Missing Values)
# 3. สร้างและเปรียบเทียบโมเดล Machine Learning (Linear Regression & Random Forest Regressor) เพื่อทำนายปริมาณการแปรรูปเนื้อสัตว์
# 4. วิเคราะห์ตัวแปรสำคัญ (Feature Importance) เพื่อระบุปัจจัยเชิงพื้นที่ที่ขับเคลื่อนการบริโภคและการผลิตเนื้อสัตว์ในแต่ละภูมิภาค

# %% [markdown]
# ## 1. Setup & Import Libraries 📦

# %%
import pandas as pd
import numpy as np
import glob
import os
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio

# ตั้งค่า renderer สำหรับ VS Code Jupyter Notebook ให้แสดงผลกราฟิกแบบตอบสนองได้
pio.renderers.default = 'notebook_connected'
pio.templates.default = 'plotly_white'

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import warnings
warnings.filterwarnings('ignore')

print("✅ Setup สำเร็จ และพร้อมใช้งาน (ใช้ Plotly สำหรับการวาดกราฟ)")
# Out:
# ✅ Setup สำเร็จ และพร้อมใช้งาน (ใช้ Plotly สำหรับการวาดกราฟ)

# %% [markdown]
# ## 2. Load and Clean Datasets 📁
# ทำการโหลดข้อมูลจำนวนสถิติการฆ่าสัตว์ และข้อมูลจำนวนประชากรสัตว์/เกษตรกรรายจังหวัด

# %%
# ฟังก์ชันทำความสะอาดข้อมูลตามกฎที่ตั้งไว้ใน EDA
def clean_and_load_csv(filepath):
    df = pd.read_csv(filepath, encoding='utf-8-sig')
    df.columns = [col.strip() for col in df.columns]
    
    def clean_cell(val):
        if pd.isna(val):
            return np.nan
        if isinstance(val, str):
            val_str = val.strip()
            if val_str == '-':
                return np.nan
            cleaned_num = val_str.replace(',', '')
            try:
                return float(cleaned_num)
            except ValueError:
                return val_str
        return val
        
    for col in df.columns:
        df[col] = df[col].apply(clean_cell)
    return df

# โหลดข้อมูล
data_dir = "Animal"
df_kill = clean_and_load_csv(os.path.join(data_dir, "animal_can_kill.csv"))

df_pig = clean_and_load_csv(os.path.join(data_dir, "total_pig.csv"))
df_cowmeat = clean_and_load_csv(os.path.join(data_dir, "total_cowmeat.csv"))
df_cow = clean_and_load_csv(os.path.join(data_dir, "total_cow.csv")) # กระบือ

df_fpig = clean_and_load_csv(os.path.join(data_dir, "total_farmer_pig.csv"))
df_fcowmeat = clean_and_load_csv(os.path.join(data_dir, "total_farmer_cowmeat.csv"))
df_fcow = clean_and_load_csv(os.path.join(data_dir, "total_farmer_cow.csv")) # เกษตรกรเลี้ยงกระบือ

print("📊 โหลดข้อมูลปศุสัตว์เสร็จสมบูรณ์!")
print(f" - ขนาดข้อมูลสถิติการฆ่า: {df_kill.shape}")
print(f" - ขนาดข้อมูลประชากรสุกร: {df_pig.shape}")
# Out:
# 📊 โหลดข้อมูลปศุสัตว์เสร็จสมบูรณ์!
#  - ขนาดข้อมูลสถิติการฆ่า: (693, 5)
#  - ขนาดข้อมูลประชากรสุกร: (385, 8)

# %% [markdown]
# ## 3. Merge Datasets & Feature Engineering 🔗
# เชื่อมโยงข้อมูลปริมาณประชากร เกษตรกร และข้อมูลสถิติการแปรรูปเนื้อสัตว์รายจังหวัดเข้าด้วยกัน

# %%
# เตรียมเชื่อมโยงข้อมูลประชากรและเกษตรกร
pig_data = df_pig[['year', 'province', 'value', 'region']].rename(columns={'value': 'pig_pop'})
cattle_data = df_cowmeat[['year', 'province', 'value']].rename(columns={'value': 'cattle_pop'})
buffalo_data = df_cow[['year', 'province', 'value']].rename(columns={'value': 'buffalo_pop'})

fpig_data = df_fpig[['year', 'province', 'value']].rename(columns={'value': 'pig_farmers'})
fcattle_data = df_fcowmeat[['year', 'province', 'value']].rename(columns={'value': 'cattle_farmers'})
fbuffalo_data = df_fcow[['year', 'province', 'value']].rename(columns={'value': 'buffalo_farmers'})

# เปลี่ยนชื่อคอลัมน์ของข้อมูลการฆ่าสัตว์ให้เข้ากันได้
kill_data = df_kill.rename(columns={
    'ปี': 'year', 
    'จังหวัด': 'province',
    'โค': 'slaughter_cow',
    'กระบือ': 'slaughter_buffalo',
    'สุกร': 'slaughter_pig'
})

# ทำการ Merge ข้อมูลเข้าด้วยกันทีละขั้น
df_merged = kill_data.copy()
for df_temp in [pig_data, cattle_data, buffalo_data, fpig_data, fcattle_data, fbuffalo_data]:
    df_merged = pd.merge(df_merged, df_temp, on=['year', 'province'], how='inner')

# จัดการค่าว่าง (NaN) ในสถิติการฆ่าสัตว์ให้เป็น 0 (หมายถึงไม่มีการฆ่าเพื่อบริโภคอย่างเป็นทางการในพื้นที่นั้น)
df_merged['slaughter_cow'] = df_merged['slaughter_cow'].fillna(0)
df_merged['slaughter_buffalo'] = df_merged['slaughter_buffalo'].fillna(0)
df_merged['slaughter_pig'] = df_merged['slaughter_pig'].fillna(0)

print(f"📈 ข้อมูลรวมพร้อมสำหรับสร้างโมเดล! มีจำนวนแถวทั้งหมด: {len(df_merged)} แถว (ครอบคลุม 5 ปี 77 จังหวัด)")
display(df_merged.head(10))
# Out:
# 📈 ข้อมูลรวมพร้อมสำหรับสร้างโมเดล! มีจำนวนแถวทั้งหมด: 385 แถว (ครอบคลุม 5 ปี 77 จังหวัด)
#    year         province  slaughter_cow  slaughter_buffalo  slaughter_pig  \
# 0  2564    กรุงเทพมหานคร         1275.0               10.0         1070.0
# 1  2564          นนทบุรี         2906.0                0.0            0.0
# 2  2564         ปทุมธานี        38729.0                0.0       426287.0
# 3  2564  พระนครศรีอยุธยา          868.0                0.0        10185.0
# 4  2564          อ่างทอง            0.0                0.0        64055.0
# 5  2564           ลพบุรี         5489.0                0.0       478186.0
# 6  2564        สิงห์บุรี          120.0                0.0        17183.0
# 7  2564           ชัยนาท          695.0              115.0        45960.0
# 8  2564          สระบุรี         2719.0                0.0       317887.0
# 9  2564      สมุทรปราการ            0.0                0.0        24960.0
#
#    pig_pop   region  cattle_pop  buffalo_pop  pig_farmers  cattle_farmers  \
# 0     2843  ภาคกลาง        4050          276            6             571
# 1        0  ภาคกลาง        1934          164            0             293
# 2     8129  ภาคกลาง        4517          682           61             272
# 3     2537  ภาคกลาง       10330         1387           63            1072
# 4    70391  ภาคกลาง       13346          766          848            1557
# 5   520745  ภาคกลาง       56548         3377         1958            3605
# 6    42923  ภาคกลาง        2879          117          301             420
# 7   160026  ภาคกลาง       49569        16416         1172            2923
# 8   167669  ภาคกลาง       30292        10982          251            2014
# 9       91  ภาคกลาง         280           32            4              35
#
#    buffalo_farmers
# 0               47
# 1               35
# 2               58
# 3              164
# 4               79
# 5              221
# 6               24
# 7             1192
# 8              660
# 9                6

# %% [markdown]
# ## 4. Train-Test Split 🕒
# เพื่อหลีกเลี่ยงการรั่วไหลของข้อมูลเวลา (Data Leakage) เราจะไม่สุ่มแยกข้อมูล แต่จะแบ่งตามปีงบประมาณ:
# - **Train Set**: ข้อมูลปี 2564 ถึง 2567 (4 ปีแรก)
# - **Test Set**: ข้อมูลปีล่าสุด 2568 (เพื่อทดสอบการทำนายอนาคต)

# %%
# คัดเลือก Features และ Targets
features = ['pig_pop', 'cattle_pop', 'buffalo_pop', 'pig_farmers', 'cattle_farmers', 'buffalo_farmers']
targets = ['slaughter_pig', 'slaughter_cow', 'slaughter_buffalo']

# แบ่ง Train / Test ตามแกนเวลา
train_mask = df_merged['year'] < 2568
test_mask = df_merged['year'] == 2568

df_train = df_merged[train_mask]
df_test = df_merged[test_mask]

X_train, y_train = df_train[features], df_train[targets]
X_test, y_test = df_test[features], df_test[targets]

print(f"📂 ข้อมูล Train (ปี 2564-2567): {len(X_train)} แถว")
print(f"📂 ข้อมูล Test (ปี 2568): {len(X_test)} แถว")
# Out:
# 📂 ข้อมูล Train (ปี 2564-2567): 308 แถว
# 📂 ข้อมูล Test (ปี 2568): 77 แถว

# %% [markdown]
# ## 5. Model Training & Evaluation 🤖
# เราจะพัฒนาโมเดลทำนายปริมาณการแปรรูปเนื้อสัตว์ 2 ประเภทหลัก เปรียบเทียบระหว่าง **Linear Regression** และ **Random Forest Regressor**
# และทำการวัดผลด้วย MAE, RMSE และ R-squared ($R^2$)

# %%
results = {}

for target in targets:
    print(f"\n{'='*20} 🎯 ทำนายเป้าหมาย: {target} {'='*20}")
    
    # 1. Linear Regression
    lr = LinearRegression()
    lr.fit(X_train, y_train[target])
    lr_pred = lr.predict(X_test)
    # ห้ามทำนายติดลบ
    lr_pred = np.clip(lr_pred, 0, None)
    
    # 2. Random Forest Regressor
    rf = RandomForestRegressor(n_estimators=100, random_state=42)
    rf.fit(X_train, y_train[target])
    rf_pred = rf.predict(X_test)
    
    # วัดค่าประสิทธิภาพ
    lr_r2 = r2_score(y_test[target], lr_pred)
    lr_mae = mean_absolute_error(y_test[target], lr_pred)
    lr_rmse = np.sqrt(mean_squared_error(y_test[target], lr_pred))
    
    rf_r2 = r2_score(y_test[target], rf_pred)
    rf_mae = mean_absolute_error(y_test[target], rf_pred)
    rf_rmse = np.sqrt(mean_squared_error(y_test[target], rf_pred))
    
    print(f"[Linear Regression] R2: {lr_r2:.4f} | MAE: {lr_mae:,.2f} | RMSE: {lr_rmse:,.2f}")
    print(f"[Random Forest]     R2: {rf_r2:.4f} | MAE: {rf_mae:,.2f} | RMSE: {rf_rmse:,.2f}")
    
    results[target] = {
        'lr_pred': lr_pred,
        'rf_pred': rf_pred,
        'y_actual': y_test[target].values,
        'rf_model': rf,
        'metrics': {
            'lr': {'R2': lr_r2, 'MAE': lr_mae, 'RMSE': lr_rmse},
            'rf': {'R2': rf_r2, 'MAE': rf_mae, 'RMSE': rf_rmse}
        }
    }
# Out:
# ==================== 🎯 ทำนายเป้าหมาย: slaughter_pig ====================
# [Linear Regression] R2: 0.0041 | MAE: 238,695.56 | RMSE: 713,626.62
# [Random Forest]     R2: 0.2183 | MAE: 154,661.88 | RMSE: 632,245.11
#
# ==================== 🎯 ทำนายเป้าหมาย: slaughter_cow ====================
# [Linear Regression] R2: 0.1067 | MAE: 3,402.85 | RMSE: 5,583.23
# [Random Forest]     R2: 0.5024 | MAE: 2,078.37 | RMSE: 4,167.18
#
# ==================== 🎯 ทำนายเป้าหมาย: slaughter_buffalo ====================
# [Linear Regression] R2: 0.1143 | MAE: 698.56 | RMSE: 1,256.25
# [Random Forest]     R2: 0.6347 | MAE: 384.28 | RMSE: 806.80

# %% [markdown]
# ## 6. Visualization 📊
# สร้างกราฟ Plotly แบบพรีเมียม เพื่อแสดงผลการเปรียบเทียบและความสำคัญของแต่ละปัจจัย

# %% [markdown]
# ### 6.1 แผนภูมิตัวแปรสำคัญ (Feature Importance)
# วิเคราะห์ว่าจำนวนประชากรสัตว์ชนิดใด หรือสัดส่วนเกษตรกรใดที่มีอิทธิพลต่อปริมาณการฆ่าในโรงงานมากที่สุด

# %%
# แสดง Feature Importance ของโมเดล Random Forest สำหรับเป้าหมายแต่ละตัว
for target in targets:
    rf_model = results[target]['rf_model']
    importances = rf_model.feature_importances_
    indices = np.argsort(importances)[::-1]
    
    imp_df = pd.DataFrame({
        'Feature': [features[i] for i in indices],
        'Importance': importances[indices]
    })
    
    # แสดงผลด้วยแผนภูมิแท่งแนวนอนโดยใช้โทนสีพรีเมียมเข้มแบบไม่มีส่วนผสมของสีขาว
    fig = px.bar(
        imp_df.sort_values('Importance', ascending=True), 
        y='Feature', 
        x='Importance', 
        orientation='h',
        title=f'ปัจจัยที่ส่งผลต่อการทำนายผลผลิต {target} สูงสุด (Random Forest)',
        color='Importance',
        color_continuous_scale=['#9575CD', '#311B92'] # โทนสีม่วงคมชัดตัดขอบสวยงาม
    )
    fig.update_layout(
        yaxis_title='ตัวแปรต้น/ปัจจัย',
        xaxis_title='ค่าน้ำหนักความสำคัญ (Relative Importance)',
        coloraxis_showscale=False,
        height=400,
        title_x=0.5,
        font=dict(size=12)
    )
    fig.show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="00bc30c8-75ed-47f0-9b90-ef5b5ebd0dc7" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("00bc30c8-75ed-47f0-9b90-ef5b5ebd0dc7")) {                    Plotly.newPlot(                        "00bc30c8-75ed-47f0-9b90-ef5b5ebd0dc7",                        [{"hovertemplate":"Importance=%{marker.color}\u003cbr\u003eFeature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"kVuIDpsLqT9Ykm+d2i2vPxXmiKK4t8E\u002fdc5QFpNkxT9YylBTEN7NP9LCa0Sje9Y\u002f"},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"kVuIDpsLqT9Ykm+d2i2vPxXmiKK4t8E\u002fdc5QFpNkxT9YylBTEN7NP9LCa0Sje9Y\u002f"},"xaxis":"x","y":["cattle_farmers","pig_farmers","buffalo_farmers","buffalo_pop","pig_pop","cattle_pop"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogra ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="6d66a472-a05b-4a1e-bd79-39b3893e640b" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6d66a472-a05b-4a1e-bd79-39b3893e640b")) {                    Plotly.newPlot(                        "6d66a472-a05b-4a1e-bd79-39b3893e640b",                        [{"hovertemplate":"Importance=%{marker.color}\u003cbr\u003eFeature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"kse3EOeTuD+MhdBzU9K4PyYwkwPwyrk\u002fZAO\u002fCvEJwj8MlCIUv5DEP\u002fhUiE5d5tk\u002f"},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"kse3EOeTuD+MhdBzU9K4PyYwkwPwyrk\u002fZAO\u002fCvEJwj8MlCIUv5DEP\u002fhUiE5d5tk\u002f"},"xaxis":"x","y":["pig_farmers","cattle_pop","pig_pop","buffalo_pop","cattle_farmers","buffalo_farmers"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"tic ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="4498b44b-7d82-4e85-91d4-3d316a09a741" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4498b44b-7d82-4e85-91d4-3d316a09a741")) {                    Plotly.newPlot(                        "4498b44b-7d82-4e85-91d4-3d316a09a741",                        [{"hovertemplate":"Importance=%{marker.color}\u003cbr\u003eFeature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"XUjbomyouT9IVAxGMDG8PzBWk2Zy\u002fcE\u002fqpnQJpwkxT+6hkB1XsjGP43dc0RilNM\u002f"},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"XUjbomyouT9IVAxGMDG8PzBWk2Zy\u002fcE\u002fqpnQJpwkxT+6hkB1XsjGP43dc0RilNM\u002f"},"xaxis":"x","y":["pig_pop","cattle_pop","cattle_farmers","buffalo_pop","pig_farmers","buffalo_farmers"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}] ...

# %% [markdown]
# ### 6.2 กราฟเปรียบเทียบค่าจริงกับการทำนาย (Actual vs. Predicted)
# เปรียบเทียบความถูกต้องของโมเดล Random Forest ในแต่ละจังหวัดสลับกับค่าจริงในปี 2568

# %%
# วาดกราฟเปรียบเทียบ Actual vs Predicted ของสุกร (ซึ่งมีข้อมูลหลากหลายและชัดเจนที่สุด)
target_show = 'slaughter_pig'
test_provinces = df_test['province'].values
actual = results[target_show]['y_actual']
pred = results[target_show]['rf_pred']

compare_df = pd.DataFrame({
    'Province': test_provinces,
    'Actual': actual,
    'Predicted': pred
}).sort_values(by='Actual', ascending=False).head(20) # แสดง 20 จังหวัดแรกที่มีปริมาณสูงสุด

fig = go.Figure()
fig.add_trace(go.Bar(
    name='จำนวนผลิตจริง (Actual)',
    x=compare_df['Province'],
    y=compare_df['Actual'],
    marker_color='#34495e'
))
fig.add_trace(go.Bar(
    name='จำนวนทำนาย (Predicted)',
    x=compare_df['Province'],
    y=compare_df['Predicted'],
    marker_color='#e74c3c'
))

fig.update_layout(
    title=f'เปรียบเทียบสถิติจริงและคำทำนายโมเดล (Actual vs. Predicted) ปี 2568 - {target_show}',
    xaxis_title='จังหวัด',
    yaxis_title='จำนวนสัตว์แปรรูป (ตัว)',
    barmode='group',
    title_x=0.5,
    legend=dict(x=0.8, y=0.9),
    height=500
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="f79ca0fe-fc71-4529-a1c7-6ea9d6bf653b" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f79ca0fe-fc71-4529-a1c7-6ea9d6bf653b")) {                    Plotly.newPlot(                        "f79ca0fe-fc71-4529-a1c7-6ea9d6bf653b",                        [{"marker":{"color":"#34495e"},"name":"\u0e08\u0e33\u0e19\u0e27\u0e19\u0e1c\u0e25\u0e34\u0e15\u0e08\u0e23\u0e34\u0e07 (Actual)","x":["\u0e19\u0e04\u0e23\u0e1b\u0e10\u0e21","\u0e2a\u0e21\u0e38\u0e17\u0e23\u0e1b\u0e23\u0e32\u0e01\u0e32\u0e23","\u0e40\u0e0a\u0e35\u0e22\u0e07\u0e43\u0e2b\u0e21\u0e48","\u0e09\u0e30\u0e40\u0e0a\u0e34\u0e07\u0e40\u0e17\u0e23\u0e32","\u0e1b\u0e17\u0e38\u0e21\u0e18\u0e32\u0e19\u0e35","\u0e02\u0e2d\u0e19\u0e41\u0e01\u0e48\u0e19","\u0e01\u0e33\u0e41\u0e1e\u0e07\u0e40\u0e1e\u0e0a\u0e23","\u0e25\u0e1e\u0e1a\u0e38\u0e23\u0e35","\u0e25\u0e33\u0e1e\u0e39\u0e19","\u0e0a\u0e25\u0e1a\u0e38\u0e23\u0e35","\u0e19\u0e04\u0e23\u0e23\u0e32\u0e0a\u0e2a\u0e35\u0e21\u0e32","\u0e23\u0e32\u0e0a\u0e1a\u0e38\u0e23\u0e35","\u0e28\u0e23\u0e35\u0e2a\u0e30\u0e40\u0e01\u0e29","\u0e40\u0e0a\u0e35\u0e22\u0e07\u0e23\u0e32\u0e22","\u0e2a\u0e23\u0e30\u0e1a\u0e38\u0e23\u0e35","\u0e2a\u0e23\u0e30\u0e41\u0e01\u0e49\u0e27","\u0e1e\u0e31\u0e17\u0e25\u0e38\u0e07","\u0e08\u0e31\u0e19\u0e17\u0e1a\u0e38\u0e23\u0e35","\u0e01\u0e32\u0e0d\u0e08\u0e19\u0e1a\u0e38\u0e23\u0e35","\u0e2b\u0e19\u0e2d\u0e07\u0e04\u0e32\u0e22"],"y":{"dtype":"f8","bdata":"AAAAAJ5IV0EAAAAAzXIzQQAAAAASyy1BAAAAAML0KkEAAAAAgmkoQQAAAAAoKyhBAAAAAKSFIUEAAAAApjAhQQAAAABMHBpBAAAAALDvF0EAAAAAHEYXQQAAAABAMBdBAAAAAIQwFEEAAAAAPAoSQQAAAABwZhFBAAAAAPAlD0EAAAAAML0NQQAAAACgiQxBAAAAAFhXCkEAAAAAkEkJQQ=="},"type":"bar"},{"marker":{"color":"#e74c3c"},"name":"\u0e08\u0e33\u0e19\u0e27\u0e19\u0e17\u0e33\u0e19\u0e32\u0e22 (Predicted)","x":["\u0e19\u0e04\u0e23\u0e1b\u0e10\u0e21","\u0e2a\u0e21\u0e38\u0e17\u0e23\u0e1b\u0e23\u0e32\u0e01\u0e32\u0e23","\u0e40\u0e0a\u0e35\u0e22\u0e07\u0e43\u0e2b\u0e21\u0e48","\u0e09\u0e30\u0e40\u0e0a\u0e34\u0e07\u0e40\u0e17\u0e23\u0e32","\u0e1b\u0e17\u0e38\u0e21\u0e18\u0e32\u0e19\u0e35","\u0e02\u0e2d\u0e19\u0e41\u0e01\u0e48\u0e19","\u0e01\u0e33\u0e41\u0e1e\u0e07\u0e40\u0e1e\u0e0a\u0e23","\u0e25\u0e1e\u0e1a\u0e38\u0e23\u0e35","\u0e25\u0e33\u0e1e\u0e39\u0e19","\u0e0a\u0e25\u0e1a\u0e38\u0e23\u0e35","\u0e19\u0e04\u0e23\u0e23\u0e32\u0e0a\u0e2a\u0e35\u0e21\u0e32","\u0e23\u0e32\u0e0a\u0e1a\u0e38\u0e23\u0e35","\u0e28\u0e23\u0e35\u0e2a\u0e30\u0e40\u0e01\u0e29","\u0e40\u0e0a\u0e35\u0e22\u0e07\u0e23\u0e32\u0e22","\u0e2a\u0e23\u0e30\u0e1a\u0e38\u0e23\u0e35","\u0e2a\u0e23\u0e30\u0e41\u0e01\u0e49\u0e27","\u0e1e\u0e31\u0e17\u0e25\u0e38\u0e07","\u0e08\u0e31\u0e19\u0e17\u0e1a\u0e38\u0e23\u0e35","\u0e01\u0e32\u0e0d\u0e08\u0e19\u0e1a\u0e38\u0e23\u0e35","\u0e2b\u0e19\u0e2d\u0e07\u0e04\u0e32\u0e22"],"y":{"dtype":"f8","bdata":"4XoUrtwoJkE9CtejntIrQRSuR2F3FihBAAAAABnhH0FI4XoU01ceQfYoXI9WnghBuB6F60LMEUE9CtcjKkggQdejcD1K3AlBrkfherEyE0EUrkfhHpcSQa5H4XruHBBBhetRuMaZ\u002fUBSuB6FmVUPQY\u002fC9ShuGxJBSOF6FOIv+EDD9ShcL3IMQfYoXI+wMRZBpHA9CjUzDkFxPQrX\u002f3X1QA=="},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111," ...

# %% [markdown]
# ### 6.3 กราฟประเมินค่า R2 Score ของโมเดล
# เปรียบเทียบประสิทธิภาพ R2 Score ระหว่างโมเดลเพื่อสรุปผลผลิตเนื้อสัตว์ทั้ง 3 ประเภท

# %%
metrics_data = []
for target in targets:
    metrics_data.append({
        'Animal': target.replace('slaughter_', '').upper(),
        'Model': 'Linear Regression',
        'R2': results[target]['metrics']['lr']['R2']
    })
    metrics_data.append({
        'Animal': target.replace('slaughter_', '').upper(),
        'Model': 'Random Forest',
        'R2': results[target]['metrics']['rf']['R2']
    })
df_metrics = pd.DataFrame(metrics_data)

fig = px.bar(
    df_metrics, 
    x='Animal', 
    y='R2', 
    color='Model', 
    barmode='group',
    title='เปรียบเทียบประสิทธิภาพ R2 Score ระหว่างโมเดล',
    color_discrete_map={'Linear Regression': '#bdc3c7', 'Random Forest': '#2ecc71'}
)
fig.update_layout(
    yaxis_title='R2 Score (ความแม่นยำเชิงสัมพัทธ์)',
    xaxis_title='ประเภทสัตว์',
    title_x=0.5,
    height=450
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="6c0dc4f8-cb5b-4f5e-b22d-ea0e4cc22009" class="plotly-graph-div" style="height:450px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6c0dc4f8-cb5b-4f5e-b22d-ea0e4cc22009")) {                    Plotly.newPlot(                        "6c0dc4f8-cb5b-4f5e-b22d-ea0e4cc22009",                        [{"alignmentgroup":"True","hovertemplate":"Model=Linear Regression\u003cbr\u003eAnimal=%{x}\u003cbr\u003eR2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Linear Regression","marker":{"color":"#bdc3c7","pattern":{"shape":""}},"name":"Linear Regression","offsetgroup":"Linear Regression","orientation":"v","showlegend":true,"textposition":"auto","x":["PIG","COW","BUFFALO"],"xaxis":"x","y":{"dtype":"f8","bdata":"gCMalu\u002fMcD+o+ZDk9E67PwjFgeFrQr0\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Model=Random Forest\u003cbr\u003eAnimal=%{x}\u003cbr\u003eR2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Random Forest","marker":{"color":"#2ecc71","pattern":{"shape":""}},"name":"Random Forest","offsetgroup":"Random Forest","orientation":"v","showlegend":true,"textposition":"auto","x":["PIG","COW","BUFFALO"],"xaxis":"x","y":{"dtype":"f8","bdata":"8NGLdAjxyz8P6bj+QBPgP+q1nRBST+Q\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[ ...
